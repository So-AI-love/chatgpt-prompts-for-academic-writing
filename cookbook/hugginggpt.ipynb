# %% [markdown]
# <a href="https://colab.research.google.com/github/So-AI-love/chatgpt-prompts-for-academic-writing/blob/main/cookbook/hugginggpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HuggingGPT
# Implementation of [HuggingGPT](https://github.com/microsoft/JARVIS). HuggingGPT is a system to connect LLMs (ChatGPT) with ML community (Hugging Face).
#
# + 🔥 Paper: https://arxiv.org/abs/2303.17580
# + 🚀 Project: https://github.com/microsoft/JARVIS
# + 🤗 Space: https://huggingface.co/spaces/microsoft/HuggingGPT

# %% [markdown]
# ## Set up tools
#
# We set up the tools available from [Transformers Agent](https://huggingface.co/docs/transformers/transformers_agents#tools). It includes a library of tools supported by Transformers and some customized tools such as image generator, video generator, text downloader and other tools.

# %%
#@title Setup
transformers_version = "v4.29.0" #@param ["main", "v4.29.0"] {allow-input: true}

print(f"Setting up everything with transformers version {transformers_version}")

# !pip install huggingface_hub>=0.14.1 git+https://github.com/huggingface/transformers@$transformers_version -q diffusers accelerate datasets torch soundfile sentencepiece opencv-python openai==0.28
# !pip install python-docx
import IPython
import soundfile as sf

def play_audio(audio):
    sf.write("speech_converted.wav", audio.numpy(), samplerate=16000)
    return IPython.display.Audio("speech_converted.wav")

from huggingface_hub import notebook_login
notebook_login()
# Out:
# Setting up everything with transformers version v4.29.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# !pip install  -U accelerate transformers
! pip install torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 56.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.29.0
#     Uninstalling transformers-4.29.0:
#       Successfully uninstalled transformers-4.29.0
# ...

# %%
from transformers import load_tool

# %%
hf_tools = [
    load_tool(tool_name)
    for tool_name in [
        "document-question-answering",
        "image-captioning",
        "image-question-answering",
        "image-segmentation",
        "speech-to-text",
        "summarization",
        "text-classification",
        "text-question-answering",
        "translation",
        "huggingface-tools/text-to-image",
        "huggingface-tools/text-to-video",
        "text-to-speech",
        "huggingface-tools/text-download",
        "huggingface-tools/image-transformation",
    ]
]
# Out:
# tool_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# text_to_image.py:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/spaces/huggingface-tools/text-to-image:
# - text_to_image.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tool_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# text_to_video.py:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/spaces/huggingface-tools/text-to-video:
# - text_to_video.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tool_config.json:   0%|          | 0.00/226 [00:00<?, ?B/s]
# text_download.py:   0%|          | 0.00/500 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Setup model and HuggingGPT
#
# We create an instance of HuggingGPT and use ChatGPT as the controller to rule the above tools.

# %%
# !pip install  langchain langchain_experimental

# !pip install transformers[agents] openai

# %%
from transformers import OpenAiAgent

agent = OpenAiAgent(model="text-davinci-003", api_key="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")
# Out:
# chat_prompt_template.txt:   0%|          | 0.00/2.83k [00:00<?, ?B/s]
# run_prompt_template.txt:   0%|          | 0.00/2.72k [00:00<?, ?B/s]

# %%
from langchain.prompts import PromptTemplate
from langchain import LLMChain
from langchain.chat_models import ChatOpenAI
import openai

os.environ['OPENAI_API_KEY'] = 'sk-qX8fYeuOxPtse7ZXgNgsT3BlbkFJETitXKSk4F32G7bXG5'

OPENAI_API_KEY="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"
openai.api_key=OPENAI_API_KEY
prompt = PromptTemplate(
    input_variables=["question","context"],
    template="{question} from {context}",
)
chain=LLMChain(llm=ChatOpenAI(openai_api_key=openai.api_key,temperature=0),prompt=prompt)

# %%
from langchain.llms import OpenAI
from langchain_experimental.autonomous_agents import HuggingGPT

# %env OPENAI_API_BASE=http://localhost:8000/v1

# %%
llm = OpenAI(model_name="gpt-3.5-turbo")
agent = HuggingGPT(llm, hf_tools)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:244: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-23-e36e3c040e35> in <cell line: 1>()
# ----> 1 llm = OpenAI(model_name="gpt-3.5-turbo")
#       2 agent = HuggingGPT(llm, hf_tools)
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py in __new__(cls, **data)
#     247                 "`from langchain.chat_models import ChatOpenAI`"
#     248             )
# --> 249             return OpenAIChat(**data)
#     250         return super().__new__(cls)
#     251
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/load/serializable.py in __init__(self, **kwargs)
#      95
# ...

# %% [markdown]
# ## Run an example
#
# Given a text, show a related image and video.

# %%
agent.run("please show me a video and an image of 'a boy is running'")
# Out:
# ==Explanation from the agent==
# I will use the following  tools: `image_generator` to generate an image, and `video_generator` to generate a video.
#
#
# ==Code generated by the agent==
# image = image_generator(prompt="a boy is running")
# video = video_generator(prompt="a boy is running")
#
#
# ==Result==
# `get_default_device` is deprecated and will be replaced with `accelerate`'s `PartialState().default_device` in version 4.36 of 🤗 Transformers.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# ...
